# %%
print('Hello World!')

#print ('hagi')
# Out:
# Hello World!
# hagi

# %%
print("dunya")
# Out:
# dunya

# %%
print("""bu benim ilk dersim
cok heyecanliyim karsimda pirlanta gibi insanlar
 var kendimi iyi hissediyorum""")
# Out:
# bu benim ilk dersim
# cok heyecanliyim karsimda pirlanta gibi insanlar
#  var kendimi iyi hissediyorum

# %%
print(""""bu benim ilk dersim
cok heyecanliyim karsimda pirlanta gibi insanlar
 var kendimi iyi hissediyorum""")
# Out:
# "bu benim ilk dersim
# cok heyecanliyim karsimda pirlanta gibi insanlar
#  var kendimi iyi hissediyorum

# %%
print(3.14)
print('3.14')
# Out:
# 3.14
# 3.14

# %%
print(''''We should have enough time for our family"''')
# Out:
# 'We should have enough time for our family"

# %%
print('''')
# Out:
#   File "<ipython-input-13-4b777b03c816>", line 1
#     print('''')
#                ^
# SyntaxError: EOF while scanning triple-quoted string literal

# %%
print('''''')

# %%
x = 7
y = 3
erzurumlular = "dadas"  # ben buraya istedigimi yazarim python catlasin
print(x + y)
# Out:
# 10

# %%
# bu single line commenttir
clarusway = "en iyi okuldur"  # bu bir inline commenttir
print ("cok onemli ")
# Out:
# cok onemli

# %%
x = 35
#burada "x" kullanicinin musterinin yasidir
print(x)
# Out:
# 35

# %%
print ("ali")  # bu bir

# %%
my_age = 30
your_age = 30
my_age = your_age
print(my_age)
# Out:
# 30
