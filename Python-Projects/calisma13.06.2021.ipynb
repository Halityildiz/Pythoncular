# %%
text1 = "I have learned strings"  # surrounded with double quotes
print(text1)
# Out:
# I have learned strings

# %%
e_mail = 'joseph@clarusway.com'  # surrounded with single quotes
print(e_mail)
# Out:
# joseph@clarusway.com

# %%
print('632')  # this is also string type
# Out:
# 632

# %%
tv_open = True  # it seems TV is on now
is_rainy = False  # I love sunny weayher

# %%
example1 = 'sometimes what you say is less important than how you say it'
print(type(example1))
# Out:
# <class 'str'>

# %%
example2 = '71'
print(type(example2))
# Out:
# <class 'int'>

# %%
example3 = 35 
print(type(example3))
# Out:
# <class 'int'>

# %%
example4 = 45.2
print(type(example4))
# Out:
# <class 'float'>

# %%
example5 = 3.14j
print(type(example5))
# Out:
# <class 'complex'>

# %%
example6 = True
print(type(example6))
# Out:
# <class 'bool'>

# %%
f = 3.14
print(type(f))
s = str(f)
print(type(s))
i = int(f)  # float deger integere donusurken virguldenden sonraki deger goz ardi edilir
print(i, '\n')
print(type(i))
# Out:
# <class 'float'>
# <class 'str'>
# 3
#
# <class 'int'>

# %%
i = 3
f = float(i)
print(f, '\n')
print(type(f))
# Out:
# 3.0
#
# <class 'float'>

# %%
x = 39
v = "11"
y = "2.5"
z = "I'm at"
print(x-int(v))
print(x-float(y))
print(z+str(x))
print(v+y)
# Out:
# 28
# 36.5
# I'm at39
# 112.5

# %%
a = 36.5
b = '30'
c = '3.5'
d = ' F is enough for room temperature.'
print(str(a+int(b)+float(c))+d)
# Out:
# 70.0 F is enough for room temperature.

# %%
color = 'red'  # str type variable
season = 'summer'
price = 250  # int type variable
pi = 3.14  # float type variable
color = 'blue'  # You can always assign a new value to a created variable
price = 100  # value of 'price' is changed
season = 'winter'  

print(color, price, season, sep=', ')
# Out:
# blue, 100, winter

# %%
x = 60
y = 6
z = 10
z = y
y = x
x = z



print(x, y, z, sep=', ')
# Out:
# 6, 60, 6

# %%
print('i', end=' ')
print('will say', end=' ')
print("'i missed you'", end=' ')
print('to my mother')
# Out:
# i will say 'i missed you' to my mother

# %%
print('smoking', 'is', 'slowly', 'killing me', sep=' + ')
# Out:
# smoking + is + slowly + killing me

# %%
x = 5
print ('value of x       : ', x)

x += 2
print ("2 more of x      : ", x, "\n") # using string expression '\n', 
                                       # we produce extra line. 
                                       # So that we had empty line.
y = 10
print ('value of y       : ', y)

y -= 2
print ("2 minus y        : ", y, "\n")

z = 6
print ('value of z       : ', z)

z *= 2
print ("2 times z        : ", z, "\n")
# Out:
# value of x       :  5
# 2 more of x      :  7
#
# value of y       :  10
# 2 minus y        :  8
#
# value of z       :  6
# 2 times z        :  12

# %%
x = 2
x += 5
print(x)
# Out:
# 7

# %%
fruit = 'Orange'
vegetable = "Tomato"
print (fruit, """ and """ , vegetable)
# Out:
# Orange  and  Tomato

# %%
print('C:\\november\number_expenditure.txt')  # \n : means new line,
# Out:
# C:\november
# umber_expenditure.txt

# %%
print('C:\\\november\number_expenditure.txt')
# Out:
# C:\
# ovember
# umber_expenditure.txt

# %%
print("one", "two", "three", sep="\t") # \t separated by tab marks
# Out:
# one	two	three

# %%
print('we', '\bare', '\bunited') # remember, normally print() function
# separates expressions by spaces
# \b : means backspace. It moves the cursor one character to the left.
# Out:
# united

# %%
# But here, in the example below, 👉🏻\ allows single-quote 👉🏻' to be ignored. So it gives no error.
print('it\'s funny to learn Python')
# Out:
# it's funny to learn Python

# %%
fruit = 'Orange'

print('Word                   : ' , fruit)
print('First letter           : ' , fruit[0])
print('Second letter          : ' , fruit[1])
print("3rd to 5th letters     : " , fruit[2:5])
print("Letter all after 3rd   : " , fruit[2:])
print('tum harfler            : ' , fruit[1:5])
# Out:
# Word                   :  Orange
# First letter           :  O
# Second letter          :  r
# 3rd to 5th letters     :  ang
# Letter all after 3rd   :  ange
# tum harfler            :  rang

# %%
halit = 'pazardan %d kg karpuz %.3f kg elma 5 kg %s alicam' % (7, 5.3, "armut")
print(halit)
# Out:
# pazardan 7 kg karpuz 5.300 kg elma 5 kg armut alicam

# %%
meyve = 'portakal'
sebze = 'ispanak'
miktar = 5
# format bolumunun sonundaki cift parantezi unutma
print('the amount of {} we bought is {} pounds'.format(meyve, miktar))
# Out:
# the amount of portakal we bought is 5 pounds

# %%
fruit = 'Orange'
vegetable = 'Tomato'
amount = 4
print('The amount of {} we bought is {} pounds'.format(fruit, amount))
# Out:
# The amount of Orange we bought is 4 pounds

# %%
print('{state} is the most {adjective} state of the {country}'.format(state='California', country='USA', adjective='crowded'))
print('{ulke} dunyadaki yolsuzluklarin en {sifat} oldugu {tanim}'.format(ulke='Turkiye', sifat='fazla', tanim='cennettir.'))
# Out:
# California is the most crowded state of the USA
# Turkiye dunyadaki yolsuzluklarin en fazla oldugu cennettir.

# %%
print("{6} {0} {5} {3} {4} {1} {2}".format('have', 6, 'months', 'a job', 'in', 'found', 'I will'))
print("{1} {0}".format('galatasaray', 'sampiyon'))
# 0 degerini atlamayalim hocam
# Out:
# I will have found a job in 6 months
# sampiyon galatasaray

# %%
print("{9} {7} {1} {10} {3} {2} {5} {8} {6} {0} {4}".format('in', 'know', 'bring', 'to', 'students.', 'out', 'best', 'teachers', 'the', 'Good', 'how'))
# Out:
# Good teachers know how to bring out the best in students.

# %%
fruit = 'Orange'
vegetable = 'Tomato'
amount = 6
output = f"The amount of {fruit} and {vegetable} we bought are totally {amount} pounds"

print(output)
meyve = 'kiraz'
sebze = 'enginar'
miktar = 5
cikti = f"pazardan alacagim {meyve} ve {sebze} icin {miktar} para lazim."
print(cikti)
# Out:
# The amount of Orange and Tomato we bought are totally 6 pounds
# pazardan alacagim kiraz ve enginar icin 5 para lazim.

# %%
my_name = 'JOSEPH'
output = f"My name is {my_name.capitalize()}"

print(output)
adim = 'HALATSAR'
cikti = f"benim adim {adim.capitalize()}dir."
print(cikti)
# Out:
# My name is Joseph
# benim adim Halatsardir.

# %%
ad = "Halit"
job = "student"
domain = "Data Science"
message = (
     f"Hi {ad}. "
     f"You are one of the {job} "
     f"in the {domain} section."
)
print(message)
# Out:
# Hi Halit. You are one of the student in the Data Science section.

# %%
#name = "Emir Altan"
#job = "student"
#domain = "matematik"
#message = f"Hi {name}. " \
#    f"You are one of the {job} " \
#    f"in the {domain} section."

#print(message)
var1 = "sleep"
var2 = "eat"
var3 = "better"
var4 = "life"
# Out:
# Hi Emir Altan. You are one of the student in the matematik section.

# %%
print('www', 'clarusway', "com", sep='.', end=' ')
print('will', end=' ')
print('open', end=' ')
print('your', end=' ')
print('path', end='.')
# Out:
# www.clarusway.com will open your path.

# %%
print("clarusway" + str(2020))
# Out:
# clarusway2020

# %%
x = 12
y = x + 21
x = 2
print(y//x)
# Out:
# 16

# %%
print(12+21)
# Out:
# 33

# %%
print("{4} {9} {1} {7} {5} {0} {6} {8} {3} {2}".format('while', 'dream', 'work.', 'and', 'Some', 'success', 'others', 'of', 'wake up', 'people'))
# Out:
# Some people dream of success while others wake up and work.

# %%
print("{3} {2} {4} {1} {0}".format('job', 'a', 'will', 'I', 'find'))
# Out:
# I will find a job

# %%
section_3_5 = "python data types and useful operations"
print(str.title(section_3_5))
# Out:
# Python Data Types And Useful Operations

# %%
print(False or {0} and [])
# Out:
# []

# %%
print(int("5" + "1"))
print(str("5" + "1"))
print("5" + "1")
# Out:
# 51
# 51
# 51

# %%
var1 = "sleep"
var2 = "eat"
var3 = "better"
var4 = "life"
sentence = f"The less you {var1} and {var2}, the {var3} your {var4} will be."
print(sentence)
# Out:
# The less you sleep and eat, the better your life will be.

# %%
city = "SARAJEVO"
text = f"I live in {city.title()}."
print(text)
# Out:
# I live in Sarajevo.

# %%
# python case sensitive bir dildir.
