# %% [markdown]
# Bu işlemler bakiye sorgulama, para yatırma, para çekme ve çıkış işlemlerini yapmasını istiyoruz.
# 1 tuşuna basınca Bakiye Sorgulama 2 tuşuna basınca Para Yatırma 3 tuşuna basınca
# Para Çekme ve q tuşuna basınca Çıkış işlemlerini yapmasını istiyoruz.
# Başlangıç bakiyesi 1000 TL olsun örneğin. birde "q" çıkış tuşuna basana
# kadar sürekli hangi işlemi yapacağımızı sorsun, ayrıca belirttiğimiz
# sayıdan ve "q" dan başka brişey girerse kullanıcı hata versin ve tekrar
# sorsun işlemin ne olduğunu... Kolay Gelsin...

# %%
main_display ='##############################\n\nClarusway Bank\'a Hosglediniz\n\
\n\n##############################\n\nIslemler\n\n1-) Bakiye Sorgulama\n\n2-) Para Yatirma\n\n3-) Para Cekme'
print(main_display)
bakiye = 1000
while True :
    soru = input('Lütfen yapmak istediginiz islemi tuslayin cikis icin \'q\' ya basin ')
    if soru == 'q':
        print('bizi tercih ettiginiz icin tesekküre ederiz')
        break
    elif soru == '1':
        print('bakiyeniz {}'.format(bakiye))
    elif soru =='2':
        soru_2 = input('Lütfen yatiralacak tutari tuslayin')
        yeni_bakiye = bakiye + int(soru_2)
        print('yeni bakiyeniz {}'.format(yeni_bakiye))
    elif soru == '3':
        soru_3 = input('Lutfen cekmek istediginiz tutari tuslayin')
        yeni_bakiye_1 =bakiye - int(soru_3)
        print('yeni bakiyeniz {}'.format(yeni_bakiye_1))
    else:
        print('Yanlis bir giris yaptiniz lütfen tekrar deneyin')
# Out:
# ##############################
#
# Clarusway Bank'a Hosglediniz
#
#
# ##############################
#
# Islemler
#
# 1-) Bakiye Sorgulama
#
# 2-) Para Yatirma
#
# 3-) Para Cekme
# Lütfen yapmak istediginiz islemi tuslayin cikis icin 'q' ya basin 1
# bakiyeniz 1000
# Lütfen yapmak istediginiz islemi tuslayin cikis icin 'q' ya basin 2
# Lütfen yatiralacak tutari tuslayin500
# yeni bakiyeniz 1500
# Lütfen yapmak istediginiz islemi tuslayin cikis icin 'q' ya basin q
# bizi tercih ettiginiz icin tesekküre ederiz

# %%
balance = 1000
while True:
    print("Welcome to the Bank Of Clarus", "\n", "\n", "Please select the action you want to take", "\n", "\n", "1-Balance inquiry", "\n", "2-Invest in", "\n", "3-Draft", "\n", "Press q to exit")
    x = str(input("Press any key"))
    if x == "1":
        print("Your Balance is:", balance)    
    elif x == "2":
        a = int(input("Add your money.Up to 40 pieces. Please entry amount"))
        balance = balance + a
        print("Your new balance is: ",balance)
    elif x == "3":
        b = int(input("Enter the amount you want to draft:"))
        if balance >= b:
            balance = balance -b
            print("Available balance is:", balance)
        else:
            print("Insufficient balance")
    elif x == "q":
        print("See you again")
        break
    else:
        print("Try again")
    question_ = str(input("Would you like to take another action? (press 'y' : yes, 'n' : no)"))
    if question_ == "y":
        True
    else:
        break
# Out:
# Welcome to the Bank Of Clarus
#
#  Please select the action you want to take
#
#  1-Balance inquiry
#  2-Invest in
#  3-Draft
#  Press q to exit
# Press any key1
# Your Balance is: 1000
# Would you like to take another action? (press 'y' : yes, 'n' : no)y
# Welcome to the Bank Of Clarus
#
#  Please select the action you want to take
#
#  1-Balance inquiry
#  2-Invest in
#  3-Draft
#  Press q to exit
# Press any key2
# Add your money.Up to 40 pieces. Please entry amount522
# Your new balance is:  1522
# Would you like to take another action? (press 'y' : yes, 'n' : no)n

# %%
dongu = True
bakiye = 1000
start = '\033[94m'
end = "\033[0;0m"
while dongu: 
    print('''
    Welcome to Clarusway Bank

    1. Bakiye Sorgulama
    2. Para Yatirma
    3. Para Cekme

    Cikis icin 'q' tusuna basiniz.
    ''')

    islem = input('Yapmak istediginiz islemin numarasini giriniz > ')
    print()
    print()
    print()
    if islem == '1':
        print(start + f"Kalan bakiyeniz {bakiye} TL'dir." + end)
    elif islem == '2':
        yatis = int(input('Yatirmak istediginiz miktari giriniz > '))
        bakiye = bakiye + yatis
    elif islem == '3':
        cekim = int(input('Cekmek istediginiz miktari giriniz >'))
        bakiye = bakiye - cekim
    elif islem.lower() == 'q':
        print(start + 'Clarusway Bank Iyi Gunler Diler.' + end)
        dongu = False
    else:
        print(start + 'Lutfen girdiginiz islem numarasini kontrol ederek tekrar giris yapiniz.' + end)
# Out:
#     Welcome to Clarusway Bank
#
#     1. Bakiye Sorgulama
#     2. Para Yatirma
#     3. Para Cekme
#
#     Cikis icin 'q' tusuna basiniz.
#
# Yapmak istediginiz islemin numarasini giriniz > 1
#
#
#
# Kalan bakiyeniz 1000 TL'dir.
#
#     Welcome to Clarusway Bank
#
#     1. Bakiye Sorgulama
#     2. Para Yatirma
#     3. Para Cekme
#
#     Cikis icin 'q' tusuna basiniz.
#
# Yapmak istediginiz islemin numarasini giriniz > 1
#
#
#
# Kalan bakiyeniz 1000 TL'dir.
#
#     Welcome to Clarusway Bank
#
#     1. Bakiye Sorgulama
#     2. Para Yatirma
#     3. Para Cekme
#
#     Cikis icin 'q' tusuna basiniz.
#
# Yapmak istediginiz islemin numarasini giriniz > q
#
#
#
# Clarusway Bank Iyi Gunler Diler.
